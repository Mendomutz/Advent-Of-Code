# %%
# Exemplo 1

input = [
    "ugknbfddgicrmopn",
    "jchzalrnumimnmhp",
    "haegwjzuvuyypxyu",
    "dvszwmarrgswjxmb"
]

vowels = ['a', 'e', 'i', 'o', 'u']
bad_strings = ['ab', 'cd', 'pq', 'xy']
totalNice = 0

def hasThreeVowels(string):
    totalVowel = 0
    for vowel in vowels:
        totalVowel += string.count(vowel)

    return totalVowel >= 3

def hasDoubleLetter(string):
    for i in range(len(string) - 1):
        if string[i] == string[i + 1]:
            return True

    return False

def notBadString(string):
    for bad in bad_strings:
        if bad in string:
            return False

    return True

for item in input:
    if hasThreeVowels(item) and hasDoubleLetter(item) and notBadString(item):
        print(item)
        totalNice += 1

print(totalNice)

# %%
# Código 1

with open("C:/Projetos/Advent Of Code/2015/puzzle inputs/5.txt", "r") as file:
    input = file.read().splitlines()

vowels = ['a', 'e', 'i', 'o', 'u']
bad_strings = ['ab', 'cd', 'pq', 'xy']
totalNice = 0

def hasThreeVowels(string):
    totalVowel = 0
    for vowel in vowels:
        totalVowel += string.count(vowel)

    return totalVowel >= 3

def hasDoubleLetter(string):
    for i in range(len(string) - 1):
        if string[i] == string[i + 1]:
            return True

    return False

def notBadString(string):
    for bad in bad_strings:
        if bad in string:
            return False

    return True

for item in input:
    if hasThreeVowels(item) and hasDoubleLetter(item) and notBadString(item):
        print(item)
        totalNice += 1

print(totalNice)

# %%
# Exemplo 2

input = [
    "qjhvhtzxzqqjkmpb",
    "xxyxx",
    "uurcxstgmygtbstg",
    "ieodomkazucvgmuy"
]

totalNice = 0

def has_repeated_pair(string):
    for i in range(len(string) - 1):
        pair = string[i:i+2]

        if pair in string[i+2:]:
            return True

    return False

def contains_separated_pair(string):
    for i in range(len(string) - 2):
        if string[i] == string[i+2]:
            return True

    return False

for item in input:
    if has_repeated_pair(item) and contains_separated_pair(item):
        totalNice += 1
        print(item)

print(totalNice)
# Out:
# qjhvhtzxzqqjkmpb
# xxyxx
# 2

# %%
# Código 2

with open("C:/Projetos/Advent Of Code/2015/puzzle inputs/5.txt", "r") as file:
    input = file.read().splitlines()

totalNice = 0

def has_repeated_pair(string):
    for i in range(len(string) - 1):
        pair = string[i:i+2]

        if pair in string[i+2:]:
            return True

    return False

def contains_separated_pair(string):
    for i in range(len(string) - 2):
        if string[i] == string[i+2]:
            return True

    return False

for item in input:
    if has_repeated_pair(item) and contains_separated_pair(item):
        totalNice += 1
        print(item)

print(totalNice)
# Out:
# skerkykytazvbupg
# jpocepxixeqjpigq
# avccmveveqwhnjdx
# kzmtudrtznhutukg
# kcrtmtshtsgixvcp
# jhhefbvbvneqzvtc
# epgygflbxlbwybzq
# eaiaquhnesvtcdsv
# pvzxkxdscdbilrdb
# rpoelfbsararhfja
# cvcizjlnzdjfjlbh
# tydnqwaqwkskcycz
# wnjltltufkgnrtgm
# ceqbneqjwyshgyge
# mrsjyjmjmbxyqbnz
# duzieldieeomrmcg
# bacrjsgrnbtmtmdl
# ucbqdveieawzucef
# vivruyvbrtaqeebr
# wxhcdrqedkdcwxli
# horzapuapgtvzizz
# rsaclclupiicstff
# qjpkeuenenwawlok
# aljalgdaqwhzhfwr
# jaxxhoulxnxnaenr
# gnfpikidnfobrrme
# blpeseqhlzfilpuf
# uqudnnqumsqcgefo
# dlzbmvmolssbqlzl
# scdwjqsdohcdrwry
# agbhxcijxjxerxyi
# ptpgttqxocjwxohi
# zmuvfkhohoznmifs
# buyuwgynbtujtura
# owbgdgdymxhhnoum
# hexvporkmherrtrn
# fnfrfwujmjwdrbdr
# fgrgxsqeducigxvr
# wqluvqlhdhskgmzj
# gxmfiehdxptweweq
# favpaqktqaqgixtv
# gvldhkewtmlwqvqv
# hqbycjweqczwjwgf
# eghwdovaynmctktk
# bnbptgihhfubxhho
# urfgjbjgzlrfsdlv
# zexpwallpocrxpvp
# tftftwedtecglavz
# rpajajukuxtchrjd
# cdcdfpsxuyrhsmag
# ekujtselepgjtaql
# bonohfnlboxiezzr
# ...
