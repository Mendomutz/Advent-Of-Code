# %%
# Exemplo 1

def parse_input():
    input = "125 17"

    return list(map(int, input.split(' ')))

def is_zero(stone):
    if stone == 0:
        return True

def change_from_zero(stone):
    if stone == 0:
        stone = 1
        return stone

def is_even_number_digit(stone):
    if len(str(stone)) % 2 == 0:
        return True

def divide_stone(stone):
    if len(str(stone)) % 2 == 0:
        stone1 = str(stone)[:len(str(stone))//2]
        stone2 = str(stone)[len(str(stone))//2:]

        return int(stone1), int(stone2)

def last_rule(stone):
    return stone * 2024

blinking = 6
INPUT = parse_input()
newList = []
oldList = INPUT

for i in range(blinking):
    for stone in oldList:
        if is_zero(stone):
            newList.append(change_from_zero(stone))

        elif is_even_number_digit(stone):
            stone1, stone2 = divide_stone(stone)
            newList.append(stone1)
            newList.append(stone2)

        else:
            newList.append(last_rule(stone))

    oldList = newList
    newList = []

print(len(oldList))
# Out:
# 22

# %%
# Código 1

import time

def parse_input():
    with open("input.txt", "r") as file:
        data = file.read()

    return list(map(int, data.split(' ')))

def is_zero(stone):
    if stone == 0:
        return True

def change_from_zero(stone):
    if stone == 0:
        stone = 1

        return stone

def is_even_number_digit(stone):
    if len(str(stone)) % 2 == 0:
        return True

def divide_stone(stone):
    if len(str(stone)) % 2 == 0:
        stone1 = str(stone)[:len(str(stone))//2]
        stone2 = str(stone)[len(str(stone))//2:]

        return int(stone1), int(stone2)

def last_rule(stone):
    return stone * 2024

blinking = 25
INPUT = parse_input()
newList = []
oldList = INPUT
start = time.time()

for i in range(blinking):
    for stone in oldList:
        if is_zero(stone):
            newList.append(change_from_zero(stone))

        elif is_even_number_digit(stone):
            stone1, stone2 = divide_stone(stone)
            newList.append(stone1)
            newList.append(stone2)

        else:
            newList.append(last_rule(stone))

    oldList = newList
    newList = []

    print(f"Tamanho da lista: {len(oldList)}, Iteração: {i}, Tempo: {time.time()-start}")

finish = time.time()
print(len(oldList), finish-start)
# Out:
# Tamanho da lista: 11, Iteração: 0, Tempo: 0.00010704994201660156
# Tamanho da lista: 14, Iteração: 1, Tempo: 0.0002856254577636719
# Tamanho da lista: 18, Iteração: 2, Tempo: 0.00030422210693359375
# Tamanho da lista: 31, Iteração: 3, Tempo: 0.00032448768615722656
# Tamanho da lista: 49, Iteração: 4, Tempo: 0.0003483295440673828
# Tamanho da lista: 79, Iteração: 5, Tempo: 0.000385284423828125
# Tamanho da lista: 118, Iteração: 6, Tempo: 0.0004343986511230469
# Tamanho da lista: 175, Iteração: 7, Tempo: 0.0005025863647460938
# Tamanho da lista: 249, Iteração: 8, Tempo: 0.0005950927734375
# Tamanho da lista: 374, Iteração: 9, Tempo: 0.0007309913635253906
# Tamanho da lista: 604, Iteração: 10, Tempo: 0.0009367465972900391
# Tamanho da lista: 894, Iteração: 11, Tempo: 0.0012242794036865234
# Tamanho da lista: 1320, Iteração: 12, Tempo: 0.001667022705078125
# Tamanho da lista: 1960, Iteração: 13, Tempo: 0.0023221969604492188
# Tamanho da lista: 3097, Iteração: 14, Tempo: 0.0032567977905273438
# Tamanho da lista: 4824, Iteração: 15, Tempo: 0.004683256149291992
# Tamanho da lista: 7019, Iteração: 16, Tempo: 0.006697893142700195
# Tamanho da lista: 10689, Iteração: 17, Tempo: 0.009849786758422852
# Tamanho da lista: 16369, Iteração: 18, Tempo: 0.014615058898925781
# Tamanho da lista: 24778, Iteração: 19, Tempo: 0.022062301635742188
# Tamanho da lista: 37855, Iteração: 20, Tempo: 0.03317832946777344
# Tamanho da lista: 57171, Iteração: 21, Tempo: 0.04967689514160156
# Tamanho da lista: 87066, Iteração: 22, Tempo: 0.07537055015563965
# Tamanho da lista: 131889, Iteração: 23, Tempo: 0.11453104019165039
# Tamanho da lista: 199753, Iteração: 24, Tempo: 0.17353439331054688
# 199753 0.17364811897277832

# %%
# Exemplo 2

from collections import Counter

def parse_input():
    input = "125 17"

    return list(map(int, input.split(' ')))

def process_stone(stone, count):
    result = Counter()

    if stone == 0:
        result [1] += count

    elif len(str(stone)) % 2 == 0:
        mid = len(str(stone)) // 2
        stone1 = int(str(stone)[:mid])
        stone2 = int(str(stone)[mid:])

        result[stone1] += count
        result[stone2] += count

    else:
        result[stone * 2024] += count

    return result

blinking = 75
input_stones = parse_input()
stones_count = Counter(input_stones)

for _ in range(blinking):
    new_counts = Counter()

    for stone, count in stones_count.items():
        new_counts.update(process_stone(stone, count))

    stones_count = new_counts

print(sum(stones_count.values()))
# Out:
# 65601038650482

# %%
# Código 2

from collections import Counter

def parse_input():
    with open("input.txt", "r") as file:
        data = file.read()

    return list(map(int, data.split(' ')))

def process_stone(stone, count):
    result = Counter()

    if stone == 0:
        result [1] += count

    elif len(str(stone)) % 2 == 0:
        mid = len(str(stone)) // 2
        stone1 = int(str(stone)[:mid])
        stone2 = int(str(stone)[mid:])

        result[stone1] += count
        result[stone2] += count

    else:
        result[stone * 2024] += count

    return result

blinking = 75
input_stones = parse_input()
stones_count = Counter(input_stones)

for _ in range(blinking):
    new_counts = Counter()

    for stone, count in stones_count.items():
        new_counts.update(process_stone(stone, count))

    stones_count = new_counts

print(sum(stones_count.values()))
# Out:
# 239413123020116
